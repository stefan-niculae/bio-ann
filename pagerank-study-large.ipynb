# %%
import networkx as nx

# %%
from sklearn.datasets import make_blobs
from sklearn.preprocessing import StandardScaler

# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout, Lambda
from keras.callbacks import LambdaCallback
from keras.utils import to_categorical
# Out:
# Using TensorFlow backend.

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from joypy import joyplot

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ---

# %%
SEED = 123

# %%
np.random.seed(SEED)

# %% [markdown]
# ## Dataset

# %%
n_features = 512
n_labels = 8

# %%
X, y = make_blobs(
    n_samples=5_000,
    n_features=n_features,
    centers=n_labels,
    cluster_std=60,  # centers are (-10, +10)
    random_state=SEED,
)

# %%
X = StandardScaler().fit_transform(X)

if n_labels > 2:
    y = to_categorical(y, n_labels)

# %% [markdown]
# ## Models

# %%
layer_sizes = [128, 128, 64, 64]
dropout_per = .4
activation = 'relu'

# %%
output_size = 1 if n_labels == 2 else n_labels
output_activation = 'sigmoid' if n_labels == 2 else 'softmax'
loss = 'binary_crossentropy' if n_labels == 2 else 'categorical_crossentropy'

# %% [markdown]
# ---

# %%
models = {}

# %%
models['no dropout'] = Sequential(
    [Dense(s, activation='relu') for s in layer_sizes] +
    [Dense(output_size, activation='sigmoid')]
)

# %%
# ignoring the entire neuron, a random one each time
models['classic dropout'] = Sequential(
    sum([[Dense(s, activation=activation), Dropout(dropout_per)] for s in layer_sizes], []) +
    [Dense(output_size, activation=output_activation)]
)

# %%
# ignoring the entire neuron, the same time every time
masks = [
    np.random.random(s)[np.newaxis] > dropout_per
    for s in [*layer_sizes[:], output_size]
]

model = Sequential()
for i, (s, m) in enumerate(zip(layer_sizes, masks)):
    kwargs = {}
    if i == 0:
        kwargs['input_dim'] = X.shape[1]
    model.add(Dense(s, activation=activation, **kwargs))
    model.add(Lambda(lambda x: x * m))
model.add(Dense(output_size, activation=output_activation))    

models['static dropout'] = model

# %%
from connections_generation import generate_masks, current_cond_dists
from bio_do import CustomConnections, MaskAdvancer

# %%
# ignoring some neuron connections, and over time adding more
masks = generate_masks([n_features, *layer_sizes, output_size], current_cond_dists())

models['bio dropout'] = Sequential(
    [CustomConnections(s, m, activation=activation) for s, m in zip(layer_sizes, masks)] +
    [CustomConnections(output_size, masks[-1], activation=output_activation)]
)

# %%
for model in models.values():
    model.compile(loss=loss, 
                  optimizer='adam', 
                  metrics=['accuracy'])

# %% [markdown]
# ## Training

# %%
weights_histories = {}
perf_histories = {}

# %%
epochs = 51
add_every = 10

# %%
# %%time
for name, model in models.items():
    print('\n\n', name)
    
    weights_history = []
    log_weights = LambdaCallback(
        on_epoch_begin=lambda epoch, logs: weights_history.append(model.get_weights())
    )
    callbacks = [log_weights]
    
    if name == 'bio dropout':
        callbacks.append(MaskAdvancer(add_every))
    
    h = model.fit(X, y,
                  validation_split=.3,
                  epochs=epochs, batch_size=64,
                  verbose=1,
                  callbacks=callbacks,
                 )
    
    weights_histories[name] = weights_history
    perf_histories[name] = h.history
# Out:
#  no dropout
# Train on 3500 samples, validate on 1500 samples
# Epoch 1/51
# 3500/3500 [==============================] - 0s 133us/step - loss: 2.0282 - acc: 0.2023 - val_loss: 1.8876 - val_acc: 0.3120
# Epoch 2/51
# 3500/3500 [==============================] - 0s 32us/step - loss: 1.3595 - acc: 0.5306 - val_loss: 1.4189 - val_acc: 0.5020
# Epoch 3/51
# 3500/3500 [==============================] - 0s 33us/step - loss: 0.5487 - acc: 0.8223 - val_loss: 1.3940 - val_acc: 0.5540
# Epoch 4/51
# 3500/3500 [==============================] - 0s 32us/step - loss: 0.1724 - acc: 0.9583 - val_loss: 1.4879 - val_acc: 0.5840
# Epoch 5/51
# 3500/3500 [==============================] - 0s 32us/step - loss: 0.0395 - acc: 0.9991 - val_loss: 1.6411 - val_acc: 0.5813
# Epoch 6/51
# 3500/3500 [==============================] - 0s 32us/step - loss: 0.0119 - acc: 1.0000 - val_loss: 1.7187 - val_acc: 0.5833
# Epoch 7/51
# 3500/3500 [==============================] - 0s 32us/step - loss: 0.0061 - acc: 1.0000 - val_loss: 1.7787 - val_acc: 0.5827
# Epoch 8/51
# 3500/3500 [==============================] - 0s 32us/step - loss: 0.0040 - acc: 1.0000 - val_loss: 1.8312 - val_acc: 0.5887
# Epoch 9/51
# 3500/3500 [==============================] - 0s 32us/step - loss: 0.0029 - acc: 1.0000 - val_loss: 1.8751 - val_acc: 0.5907
# Epoch 10/51
# 3500/3500 [==============================] - 0s 30us/step - loss: 0.0022 - acc: 1.0000 - val_loss: 1.9173 - val_acc: 0.5907
# Epoch 11/51
# 3500/3500 [==============================] - 0s 29us/step - loss: 0.0018 - acc: 1.0000 - val_loss: 1.9489 - val_acc: 0.5920
# Epoch 12/51
# 3500/3500 [==============================] - 0s 28us/step - loss: 0.0014 - acc: 1.0000 - val_loss: 1.9826 - val_acc: 0.5953
# Epoch 13/51
# 3500/3500 [==============================] - 0s 29us/step - loss: 0.0012 - acc: 1.0000 - val_loss: 2.0140 - val_acc: 0.5913
# Epoch 14/51
# 3500/3500 [==============================] - 0s 28us/step - loss: 9.9761e-04 - acc: 1.0000 - val_loss: 2.0392 - val_acc: 0.5947
# Epoch 15/51
# 3500/3500 [==============================] - 0s 29us/step - loss: 8.4907e-04 - acc: 1.0000 - val_loss: 2.0691 - val_acc: 0.5960
# Epoch 16/51
# 3500/3500 [==============================] - 0s 29us/step - loss: 7.3142e-04 - acc: 1.0000 - val_loss: 2.0888 - val_acc: 0.5927
# Epoch 17/51
# 3500/3500 [==============================] - 0s 29us/step - loss: 6.3847e-04 - acc: 1.0000 - val_loss: 2.1136 - val_acc: 0.5967
# Epoch 18/51
# 3500/3500 [==============================] - 0s 29us/step - loss: 5.6017e-04 - acc: 1.0000 - val_loss: 2.1331 - val_acc: 0.5940
# Epoch 19/51
# 3500/3500 [==============================] - 0s 28us/step - loss: 4.9528e-04 - acc: 1.0000 - val_loss: 2.1530 - val_acc: 0.5960
# Epoch 20/51
# 3500/3500 [==============================] - 0s 29us/step - loss: 4.4175e-04 - acc: 1.0000 - val_loss: 2.1692 - val_acc: 0.5967
# Epoch 21/51
# 3500/3500 [==============================] - 0s 28us/step - loss: 3.9639e-04 - acc: 1.0000 - val_loss: 2.1886 - val_acc: 0.5960
# Epoch 22/51
# 3500/3500 [==============================] - 0s 29us/step - loss: 3.5712e-04 - acc: 1.0000 - val_loss: 2.2029 - val_acc: 0.5960
# Epoch 23/51
# 3500/3500 [==============================] - 0s 28us/step - loss: 3.2215e-04 - acc: 1.0000 - val_loss: 2.2212 - val_acc: 0.5960
# Epoch 24/51
# 3500/3500 [==============================] - 0s 28us/step - loss: 2.9256e-04 - acc: 1.0000 - val_loss: 2.2358 - val_acc: 0.5967
# Epoch 25/51
# 3500/3500 [==============================] - 0s 29us/step - loss: 2.6687e-04 - acc: 1.0000 - val_loss: 2.2515 - val_acc: 0.5960
# Epoch 26/51
# 3500/3500 [==============================] - 0s 28us/step - loss: 2.4412e-04 - acc: 1.0000 - val_loss: 2.2657 - val_acc: 0.5967
# Epoch 27/51
# 3500/3500 [==============================] - 0s 28us/step - loss: 2.2427e-04 - acc: 1.0000 - val_loss: 2.2794 - val_acc: 0.5960
# Epoch 28/51
# 3500/3500 [==============================] - 0s 28us/step - loss: 2.0614e-04 - acc: 1.0000 - val_loss: 2.2921 - val_acc: 0.5960
# Epoch 29/51
# 3500/3500 [==============================] - 0s 29us/step - loss: 1.9027e-04 - acc: 1.0000 - val_loss: 2.3048 - val_acc: 0.5960
# Epoch 30/51
# 3500/3500 [==============================] - 0s 28us/step - loss: 1.7591e-04 - acc: 1.0000 - val_loss: 2.3165 - val_acc: 0.5967
# Epoch 31/51
# 3500/3500 [==============================] - 0s 28us/step - loss: 1.6310e-04 - acc: 1.0000 - val_loss: 2.3287 - val_acc: 0.5967
# Epoch 32/51
# 3500/3500 [==============================] - 0s 29us/step - loss: 1.5138e-04 - acc: 1.0000 - val_loss: 2.3407 - val_acc: 0.5967
# Epoch 33/51
# 3500/3500 [==============================] - 0s 28us/step - loss: 1.4084e-04 - acc: 1.0000 - val_loss: 2.3508 - val_acc: 0.5980
# Epoch 34/51
# 3500/3500 [==============================] - 0s 28us/step - loss: 1.3145e-04 - acc: 1.0000 - val_loss: 2.3621 - val_acc: 0.5973
# Epoch 35/51
# 3500/3500 [==============================] - 0s 31us/step - loss: 1.2262e-04 - acc: 1.0000 - val_loss: 2.3738 - val_acc: 0.5960
# Epoch 36/51
# 3500/3500 [==============================] - 0s 28us/step - loss: 1.1463e-04 - acc: 1.0000 - val_loss: 2.3838 - val_acc: 0.5967
# Epoch 37/51
# 3500/3500 [==============================] - 0s 29us/step - loss: 1.0739e-04 - acc: 1.0000 - val_loss: 2.3936 - val_acc: 0.5967
# Epoch 38/51
# 3500/3500 [==============================] - 0s 28us/step - loss: 1.0080e-04 - acc: 1.0000 - val_loss: 2.4026 - val_acc: 0.5980
# Epoch 39/51
# 3500/3500 [==============================] - 0s 28us/step - loss: 9.4614e-05 - acc: 1.0000 - val_loss: 2.4127 - val_acc: 0.5973
# Epoch 40/51
# 3500/3500 [==============================] - 0s 29us/step - loss: 8.8945e-05 - acc: 1.0000 - val_loss: 2.4225 - val_acc: 0.5967
# Epoch 41/51
# 3500/3500 [==============================] - 0s 35us/step - loss: 8.3791e-05 - acc: 1.0000 - val_loss: 2.4317 - val_acc: 0.5973
# Epoch 42/51
# 3500/3500 [==============================] - 0s 29us/step - loss: 7.8905e-05 - acc: 1.0000 - val_loss: 2.4405 - val_acc: 0.5980
# Epoch 43/51
# 3500/3500 [==============================] - 0s 29us/step - loss: 7.4437e-05 - acc: 1.0000 - val_loss: 2.4488 - val_acc: 0.5967
# Epoch 44/51
# 3500/3500 [==============================] - 0s 28us/step - loss: 7.0313e-05 - acc: 1.0000 - val_loss: 2.4580 - val_acc: 0.5980
# Epoch 45/51
# 3500/3500 [==============================] - 0s 29us/step - loss: 6.6478e-05 - acc: 1.0000 - val_loss: 2.4659 - val_acc: 0.5973
# Epoch 46/51
# 3500/3500 [==============================] - 0s 29us/step - loss: 6.2979e-05 - acc: 1.0000 - val_loss: 2.4747 - val_acc: 0.5973
# Epoch 47/51
# 3500/3500 [==============================] - 0s 29us/step - loss: 5.9571e-05 - acc: 1.0000 - val_loss: 2.4830 - val_acc: 0.5973
# Epoch 48/51
# 3500/3500 [==============================] - 0s 29us/step - loss: 5.6494e-05 - acc: 1.0000 - val_loss: 2.4910 - val_acc: 0.5967
# Epoch 49/51
# 3500/3500 [==============================] - 0s 29us/step - loss: 5.3578e-05 - acc: 1.0000 - val_loss: 2.4991 - val_acc: 0.5960
# Epoch 50/51
# 3500/3500 [==============================] - 0s 28us/step - loss: 5.0875e-05 - acc: 1.0000 - val_loss: 2.5074 - val_acc: 0.5973
# Epoch 51/51
# 3500/3500 [==============================] - 0s 29us/step - loss: 4.8304e-05 - acc: 1.0000 - val_loss: 2.5148 - val_acc: 0.5967
#
#
#  classic dropout
# Train on 3500 samples, validate on 1500 samples
# Epoch 1/51
# 3500/3500 [==============================] - 1s 176us/step - loss: 2.2633 - acc: 0.1271 - val_loss: 2.0741 - val_acc: 0.1393
# Epoch 2/51
# 3500/3500 [==============================] - 0s 41us/step - loss: 2.1094 - acc: 0.1371 - val_loss: 2.0744 - val_acc: 0.1353
# Epoch 3/51
# 3500/3500 [==============================] - 0s 41us/step - loss: 2.0885 - acc: 0.1460 - val_loss: 2.0727 - val_acc: 0.1653
# Epoch 4/51
# 3500/3500 [==============================] - 0s 41us/step - loss: 2.0849 - acc: 0.1357 - val_loss: 2.0714 - val_acc: 0.1747
# Epoch 5/51
# 3500/3500 [==============================] - 0s 41us/step - loss: 2.0686 - acc: 0.1589 - val_loss: 2.0666 - val_acc: 0.1907
# Epoch 6/51
# 3500/3500 [==============================] - 0s 41us/step - loss: 2.0490 - acc: 0.1840 - val_loss: 2.0486 - val_acc: 0.2380
# Epoch 7/51
# 3500/3500 [==============================] - 0s 41us/step - loss: 2.0181 - acc: 0.2034 - val_loss: 2.0033 - val_acc: 0.2547
# Epoch 8/51
# 3500/3500 [==============================] - 0s 37us/step - loss: 1.9619 - acc: 0.2311 - val_loss: 1.9326 - val_acc: 0.2980
# Epoch 9/51
# 3500/3500 [==============================] - 0s 37us/step - loss: 1.8944 - acc: 0.2594 - val_loss: 1.8690 - val_acc: 0.3380
# Epoch 10/51
# 3500/3500 [==============================] - 0s 37us/step - loss: 1.8083 - acc: 0.3109 - val_loss: 1.7920 - val_acc: 0.3693
# Epoch 11/51
# 3500/3500 [==============================] - 0s 38us/step - loss: 1.6861 - acc: 0.3654 - val_loss: 1.6902 - val_acc: 0.4073
# Epoch 12/51
# 3500/3500 [==============================] - 0s 40us/step - loss: 1.5915 - acc: 0.4069 - val_loss: 1.6116 - val_acc: 0.4500
# Epoch 13/51
# 3500/3500 [==============================] - 0s 37us/step - loss: 1.4662 - acc: 0.4720 - val_loss: 1.5408 - val_acc: 0.4660
# Epoch 14/51
# 3500/3500 [==============================] - 0s 37us/step - loss: 1.3769 - acc: 0.5143 - val_loss: 1.4882 - val_acc: 0.4933
# Epoch 15/51
# 3500/3500 [==============================] - 0s 37us/step - loss: 1.2285 - acc: 0.5729 - val_loss: 1.4431 - val_acc: 0.5167
# Epoch 16/51
# 3500/3500 [==============================] - 0s 37us/step - loss: 1.1386 - acc: 0.6103 - val_loss: 1.4081 - val_acc: 0.5273
# Epoch 17/51
# 3500/3500 [==============================] - 0s 36us/step - loss: 1.0298 - acc: 0.6511 - val_loss: 1.3745 - val_acc: 0.5587
# Epoch 18/51
# 3500/3500 [==============================] - 0s 36us/step - loss: 0.9465 - acc: 0.6806 - val_loss: 1.3574 - val_acc: 0.5800
# Epoch 19/51
# 3500/3500 [==============================] - 0s 37us/step - loss: 0.8988 - acc: 0.7123 - val_loss: 1.3215 - val_acc: 0.5900
# Epoch 20/51
# 3500/3500 [==============================] - 0s 37us/step - loss: 0.8227 - acc: 0.7420 - val_loss: 1.3362 - val_acc: 0.5860
# Epoch 21/51
# 3500/3500 [==============================] - 0s 38us/step - loss: 0.7404 - acc: 0.7726 - val_loss: 1.3527 - val_acc: 0.6033
# Epoch 22/51
# 3500/3500 [==============================] - 0s 37us/step - loss: 0.6639 - acc: 0.7957 - val_loss: 1.3565 - val_acc: 0.6080
# Epoch 23/51
# 3500/3500 [==============================] - 0s 37us/step - loss: 0.6504 - acc: 0.8091 - val_loss: 1.3390 - val_acc: 0.6087
# Epoch 24/51
# 3500/3500 [==============================] - 0s 36us/step - loss: 0.5900 - acc: 0.8303 - val_loss: 1.3720 - val_acc: 0.6207
# Epoch 25/51
# 3500/3500 [==============================] - 0s 38us/step - loss: 0.5705 - acc: 0.8277 - val_loss: 1.3821 - val_acc: 0.6307
# Epoch 26/51
# 3500/3500 [==============================] - 0s 43us/step - loss: 0.5236 - acc: 0.8454 - val_loss: 1.4315 - val_acc: 0.6153
# Epoch 27/51
# 3500/3500 [==============================] - 0s 42us/step - loss: 0.4688 - acc: 0.8689 - val_loss: 1.4261 - val_acc: 0.6320
# Epoch 28/51
# 3500/3500 [==============================] - 0s 42us/step - loss: 0.4401 - acc: 0.8714 - val_loss: 1.4431 - val_acc: 0.6313
# Epoch 29/51
# 3500/3500 [==============================] - 0s 37us/step - loss: 0.4442 - acc: 0.8694 - val_loss: 1.4637 - val_acc: 0.6240
# Epoch 30/51
# 3500/3500 [==============================] - 0s 37us/step - loss: 0.4338 - acc: 0.8854 - val_loss: 1.4743 - val_acc: 0.6400
# Epoch 31/51
# 3500/3500 [==============================] - 0s 37us/step - loss: 0.3860 - acc: 0.8889 - val_loss: 1.4964 - val_acc: 0.6460
# Epoch 32/51
# 3500/3500 [==============================] - 0s 39us/step - loss: 0.3618 - acc: 0.8963 - val_loss: 1.5221 - val_acc: 0.6380
# Epoch 33/51
# 3500/3500 [==============================] - 0s 40us/step - loss: 0.3632 - acc: 0.9003 - val_loss: 1.5116 - val_acc: 0.6400
# Epoch 34/51
# 3500/3500 [==============================] - 0s 36us/step - loss: 0.3212 - acc: 0.9143 - val_loss: 1.5965 - val_acc: 0.6433
# Epoch 35/51
# 3500/3500 [==============================] - 0s 36us/step - loss: 0.3040 - acc: 0.9189 - val_loss: 1.6195 - val_acc: 0.6420
# Epoch 36/51
# 3500/3500 [==============================] - 0s 36us/step - loss: 0.2984 - acc: 0.9166 - val_loss: 1.6521 - val_acc: 0.6380
# Epoch 37/51
# 3500/3500 [==============================] - 0s 36us/step - loss: 0.2994 - acc: 0.9197 - val_loss: 1.6714 - val_acc: 0.6320
# Epoch 38/51
# 3500/3500 [==============================] - 0s 36us/step - loss: 0.2839 - acc: 0.9269 - val_loss: 1.6649 - val_acc: 0.6293
# Epoch 39/51
# 3500/3500 [==============================] - 0s 36us/step - loss: 0.2835 - acc: 0.9277 - val_loss: 1.6724 - val_acc: 0.6300
# Epoch 40/51
# 3500/3500 [==============================] - 0s 36us/step - loss: 0.2667 - acc: 0.9314 - val_loss: 1.6944 - val_acc: 0.6353
# Epoch 41/51
# 3500/3500 [==============================] - 0s 36us/step - loss: 0.2397 - acc: 0.9397 - val_loss: 1.7487 - val_acc: 0.6407
# Epoch 42/51
# 3500/3500 [==============================] - 0s 36us/step - loss: 0.2412 - acc: 0.9354 - val_loss: 1.7784 - val_acc: 0.6340
# Epoch 43/51
# 3500/3500 [==============================] - 0s 36us/step - loss: 0.2269 - acc: 0.9429 - val_loss: 1.8090 - val_acc: 0.6333
# Epoch 44/51
# 3500/3500 [==============================] - 0s 36us/step - loss: 0.2192 - acc: 0.9400 - val_loss: 1.8218 - val_acc: 0.6333
# Epoch 45/51
# 3500/3500 [==============================] - 0s 36us/step - loss: 0.2226 - acc: 0.9397 - val_loss: 1.8614 - val_acc: 0.6213
# Epoch 46/51
# 3500/3500 [==============================] - 0s 36us/step - loss: 0.2123 - acc: 0.9471 - val_loss: 1.9444 - val_acc: 0.6253
# Epoch 47/51
# 3500/3500 [==============================] - 0s 42us/step - loss: 0.1915 - acc: 0.9514 - val_loss: 1.9562 - val_acc: 0.6247
# Epoch 48/51
# 3500/3500 [==============================] - 0s 42us/step - loss: 0.2045 - acc: 0.9531 - val_loss: 1.9860 - val_acc: 0.6260
# Epoch 49/51
# 3500/3500 [==============================] - 0s 42us/step - loss: 0.1892 - acc: 0.9509 - val_loss: 1.9133 - val_acc: 0.6353
# Epoch 50/51
# 3500/3500 [==============================] - 0s 42us/step - loss: 0.1919 - acc: 0.9491 - val_loss: 1.9124 - val_acc: 0.6300
# Epoch 51/51
# 3500/3500 [==============================] - 0s 43us/step - loss: 0.2164 - acc: 0.9486 - val_loss: 1.9051 - val_acc: 0.6267
#
#
#  static dropout
# Train on 3500 samples, validate on 1500 samples
# Epoch 1/51
# 3500/3500 [==============================] - 0s 139us/step - loss: 2.0671 - acc: 0.1726 - val_loss: 2.0363 - val_acc: 0.2133
# Epoch 2/51
# 3500/3500 [==============================] - 0s 35us/step - loss: 1.7480 - acc: 0.4000 - val_loss: 1.6383 - val_acc: 0.4060
# Epoch 3/51
# 3500/3500 [==============================] - 0s 34us/step - loss: 0.9388 - acc: 0.6971 - val_loss: 1.3478 - val_acc: 0.5327
# Epoch 4/51
# 3500/3500 [==============================] - 0s 32us/step - loss: 0.4006 - acc: 0.8811 - val_loss: 1.3971 - val_acc: 0.5733
# Epoch 5/51
# 3500/3500 [==============================] - 0s 32us/step - loss: 0.1531 - acc: 0.9666 - val_loss: 1.5846 - val_acc: 0.5813
# Epoch 6/51
# 3500/3500 [==============================] - 0s 32us/step - loss: 0.0471 - acc: 0.9954 - val_loss: 1.7570 - val_acc: 0.5733
# Epoch 7/51
# 3500/3500 [==============================] - 0s 32us/step - loss: 0.0173 - acc: 0.9994 - val_loss: 1.8507 - val_acc: 0.5767
# Epoch 8/51
# 3500/3500 [==============================] - 0s 31us/step - loss: 0.0083 - acc: 1.0000 - val_loss: 1.9374 - val_acc: 0.5767
# Epoch 9/51
# 3500/3500 [==============================] - 0s 31us/step - loss: 0.0054 - acc: 1.0000 - val_loss: 2.0130 - val_acc: 0.5747
# Epoch 10/51
# 3500/3500 [==============================] - 0s 32us/step - loss: 0.0039 - acc: 1.0000 - val_loss: 2.0676 - val_acc: 0.5787
# Epoch 11/51
# 3500/3500 [==============================] - 0s 31us/step - loss: 0.0029 - acc: 1.0000 - val_loss: 2.1140 - val_acc: 0.5753
# Epoch 12/51
# 3500/3500 [==============================] - 0s 32us/step - loss: 0.0023 - acc: 1.0000 - val_loss: 2.1633 - val_acc: 0.5780
# Epoch 13/51
# 3500/3500 [==============================] - 0s 32us/step - loss: 0.0019 - acc: 1.0000 - val_loss: 2.2013 - val_acc: 0.5767
# Epoch 14/51
# 3500/3500 [==============================] - 0s 32us/step - loss: 0.0016 - acc: 1.0000 - val_loss: 2.2386 - val_acc: 0.5767
# Epoch 15/51
# 3500/3500 [==============================] - 0s 32us/step - loss: 0.0013 - acc: 1.0000 - val_loss: 2.2701 - val_acc: 0.5787
# Epoch 16/51
# 3500/3500 [==============================] - 0s 32us/step - loss: 0.0011 - acc: 1.0000 - val_loss: 2.3003 - val_acc: 0.5780
# Epoch 17/51
# 3500/3500 [==============================] - 0s 32us/step - loss: 9.6717e-04 - acc: 1.0000 - val_loss: 2.3297 - val_acc: 0.5773
# Epoch 18/51
# 3500/3500 [==============================] - 0s 32us/step - loss: 8.4274e-04 - acc: 1.0000 - val_loss: 2.3552 - val_acc: 0.5780
# Epoch 19/51
# 3500/3500 [==============================] - 0s 32us/step - loss: 7.4261e-04 - acc: 1.0000 - val_loss: 2.3812 - val_acc: 0.5793
# Epoch 20/51
# 3500/3500 [==============================] - 0s 32us/step - loss: 6.5804e-04 - acc: 1.0000 - val_loss: 2.4058 - val_acc: 0.5787
# Epoch 21/51
# 3500/3500 [==============================] - 0s 32us/step - loss: 5.8636e-04 - acc: 1.0000 - val_loss: 2.4277 - val_acc: 0.5793
# Epoch 22/51
# 3500/3500 [==============================] - 0s 32us/step - loss: 5.2626e-04 - acc: 1.0000 - val_loss: 2.4485 - val_acc: 0.5787
# Epoch 23/51
# 3500/3500 [==============================] - 0s 32us/step - loss: 4.7484e-04 - acc: 1.0000 - val_loss: 2.4696 - val_acc: 0.5787
# Epoch 24/51
# 3500/3500 [==============================] - 0s 31us/step - loss: 4.2983e-04 - acc: 1.0000 - val_loss: 2.4885 - val_acc: 0.5800
# Epoch 25/51
# 3500/3500 [==============================] - 0s 32us/step - loss: 3.9043e-04 - acc: 1.0000 - val_loss: 2.5076 - val_acc: 0.5793
# Epoch 26/51
# 3500/3500 [==============================] - 0s 32us/step - loss: 3.5680e-04 - acc: 1.0000 - val_loss: 2.5269 - val_acc: 0.5793
# Epoch 27/51
# 3500/3500 [==============================] - 0s 32us/step - loss: 3.2674e-04 - acc: 1.0000 - val_loss: 2.5437 - val_acc: 0.5807
# Epoch 28/51
# 3500/3500 [==============================] - 0s 32us/step - loss: 2.9999e-04 - acc: 1.0000 - val_loss: 2.5593 - val_acc: 0.5800
# Epoch 29/51
# 3500/3500 [==============================] - 0s 31us/step - loss: 2.7634e-04 - acc: 1.0000 - val_loss: 2.5755 - val_acc: 0.5807
# Epoch 30/51
# 3500/3500 [==============================] - 0s 38us/step - loss: 2.5516e-04 - acc: 1.0000 - val_loss: 2.5922 - val_acc: 0.5807
# Epoch 31/51
# 3500/3500 [==============================] - 0s 38us/step - loss: 2.3595e-04 - acc: 1.0000 - val_loss: 2.6075 - val_acc: 0.5807
# Epoch 32/51
# 3500/3500 [==============================] - 0s 37us/step - loss: 2.1902e-04 - acc: 1.0000 - val_loss: 2.6211 - val_acc: 0.5807
# Epoch 33/51
# 3500/3500 [==============================] - 0s 37us/step - loss: 2.0347e-04 - acc: 1.0000 - val_loss: 2.6351 - val_acc: 0.5813
# Epoch 34/51
# 3500/3500 [==============================] - 0s 38us/step - loss: 1.8961e-04 - acc: 1.0000 - val_loss: 2.6487 - val_acc: 0.5807
# Epoch 35/51
# 3500/3500 [==============================] - 0s 37us/step - loss: 1.7680e-04 - acc: 1.0000 - val_loss: 2.6620 - val_acc: 0.5807
# Epoch 36/51
# 3500/3500 [==============================] - 0s 37us/step - loss: 1.6524e-04 - acc: 1.0000 - val_loss: 2.6756 - val_acc: 0.5807
# Epoch 37/51
# 3500/3500 [==============================] - 0s 35us/step - loss: 1.5463e-04 - acc: 1.0000 - val_loss: 2.6872 - val_acc: 0.5813
# Epoch 38/51
# 3500/3500 [==============================] - 0s 33us/step - loss: 1.4493e-04 - acc: 1.0000 - val_loss: 2.7002 - val_acc: 0.5813
# Epoch 39/51
# 3500/3500 [==============================] - 0s 32us/step - loss: 1.3612e-04 - acc: 1.0000 - val_loss: 2.7126 - val_acc: 0.5800
# Epoch 40/51
# 3500/3500 [==============================] - 0s 32us/step - loss: 1.2796e-04 - acc: 1.0000 - val_loss: 2.7244 - val_acc: 0.5800
# Epoch 41/51
# 3500/3500 [==============================] - 0s 32us/step - loss: 1.2032e-04 - acc: 1.0000 - val_loss: 2.7360 - val_acc: 0.5800
# Epoch 42/51
# 3500/3500 [==============================] - 0s 37us/step - loss: 1.1343e-04 - acc: 1.0000 - val_loss: 2.7475 - val_acc: 0.5807
# Epoch 43/51
# 3500/3500 [==============================] - 0s 38us/step - loss: 1.0696e-04 - acc: 1.0000 - val_loss: 2.7583 - val_acc: 0.5800
# Epoch 44/51
# 3500/3500 [==============================] - 0s 37us/step - loss: 1.0090e-04 - acc: 1.0000 - val_loss: 2.7693 - val_acc: 0.5807
# Epoch 45/51
# 3500/3500 [==============================] - 0s 37us/step - loss: 9.5371e-05 - acc: 1.0000 - val_loss: 2.7798 - val_acc: 0.5807
# Epoch 46/51
# 3500/3500 [==============================] - 0s 37us/step - loss: 9.0227e-05 - acc: 1.0000 - val_loss: 2.7903 - val_acc: 0.5807
# Epoch 47/51
# 3500/3500 [==============================] - 0s 35us/step - loss: 8.5469e-05 - acc: 1.0000 - val_loss: 2.8001 - val_acc: 0.5813
# Epoch 48/51
# 3500/3500 [==============================] - 0s 38us/step - loss: 8.0964e-05 - acc: 1.0000 - val_loss: 2.8104 - val_acc: 0.5813
# Epoch 49/51
# 3500/3500 [==============================] - 0s 36us/step - loss: 7.6774e-05 - acc: 1.0000 - val_loss: 2.8205 - val_acc: 0.5813
# Epoch 50/51
# 3500/3500 [==============================] - 0s 37us/step - loss: 7.2847e-05 - acc: 1.0000 - val_loss: 2.8299 - val_acc: 0.5813
# Epoch 51/51
# 3500/3500 [==============================] - 0s 35us/step - loss: 6.9204e-05 - acc: 1.0000 - val_loss: 2.8397 - val_acc: 0.5807
#
#
#  bio dropout
# Train on 3500 samples, validate on 1500 samples
# Epoch 1/51
# 3500/3500 [==============================] - 1s 171us/step - loss: 2.0797 - acc: 0.1223 - val_loss: 2.0796 - val_acc: 0.1140
# Epoch 2/51
# 3500/3500 [==============================] - 0s 33us/step - loss: 2.0789 - acc: 0.1297 - val_loss: 2.0791 - val_acc: 0.1147
# Epoch 3/51
# 3500/3500 [==============================] - 0s 31us/step - loss: 2.0767 - acc: 0.1529 - val_loss: 2.0754 - val_acc: 0.1753
# Epoch 4/51
# 3500/3500 [==============================] - 0s 32us/step - loss: 2.0633 - acc: 0.2086 - val_loss: 2.0553 - val_acc: 0.1433
# Epoch 5/51
# 3500/3500 [==============================] - 0s 32us/step - loss: 2.0033 - acc: 0.2497 - val_loss: 1.9788 - val_acc: 0.2513
# Epoch 6/51
# 3500/3500 [==============================] - 0s 33us/step - loss: 1.8392 - acc: 0.3857 - val_loss: 1.8373 - val_acc: 0.3413
# Epoch 7/51
# 3500/3500 [==============================] - 0s 34us/step - loss: 1.6027 - acc: 0.4677 - val_loss: 1.6982 - val_acc: 0.3753
# Epoch 8/51
# 3500/3500 [==============================] - 0s 33us/step - loss: 1.4151 - acc: 0.5243 - val_loss: 1.6514 - val_acc: 0.3953
# Epoch 9/51
# 3500/3500 [==============================] - 0s 31us/step - loss: 1.2905 - acc: 0.5517 - val_loss: 1.6161 - val_acc: 0.4027
# Epoch 10/51
# 3500/3500 [==============================] - 0s 31us/step - loss: 1.2023 - acc: 0.5826 - val_loss: 1.6179 - val_acc: 0.4200
# Epoch 11/51
# 3500/3500 [==============================] - 0s 31us/step - loss: 1.1395 - acc: 0.6037 - val_loss: 1.6086 - val_acc: 0.4240
# Epoch 12/51
# 3500/3500 [==============================] - 0s 30us/step - loss: 1.0856 - acc: 0.6240 - val_loss: 1.6215 - val_acc: 0.4220
# Epoch 13/51
# 3500/3500 [==============================] - 0s 30us/step - loss: 1.0365 - acc: 0.6400 - val_loss: 1.6241 - val_acc: 0.4307
# Epoch 14/51
# 3500/3500 [==============================] - 0s 31us/step - loss: 1.0023 - acc: 0.6489 - val_loss: 1.6400 - val_acc: 0.4307
# Epoch 15/51
# 3500/3500 [==============================] - 0s 31us/step - loss: 0.9668 - acc: 0.6617 - val_loss: 1.6479 - val_acc: 0.4393
# Epoch 16/51
# 3500/3500 [==============================] - 0s 30us/step - loss: 0.9391 - acc: 0.6723 - val_loss: 1.6715 - val_acc: 0.4307
# Epoch 17/51
# 3500/3500 [==============================] - 0s 31us/step - loss: 0.9081 - acc: 0.6829 - val_loss: 1.6632 - val_acc: 0.4480
# Epoch 18/51
# 3500/3500 [==============================] - 0s 29us/step - loss: 0.8831 - acc: 0.6960 - val_loss: 1.6712 - val_acc: 0.4520
# Epoch 19/51
# 3500/3500 [==============================] - 0s 29us/step - loss: 0.8600 - acc: 0.7020 - val_loss: 1.6929 - val_acc: 0.4427
# Epoch 20/51
# 3500/3500 [==============================] - 0s 31us/step - loss: 0.8405 - acc: 0.7071 - val_loss: 1.6995 - val_acc: 0.4467
# Epoch 21/51
# 3500/3500 [==============================] - 0s 30us/step - loss: 0.8189 - acc: 0.7186 - val_loss: 1.7307 - val_acc: 0.4527
# Epoch 22/51
# 3500/3500 [==============================] - 0s 30us/step - loss: 0.7965 - acc: 0.7300 - val_loss: 1.7184 - val_acc: 0.4520
# Epoch 23/51
# 3500/3500 [==============================] - 0s 31us/step - loss: 0.7809 - acc: 0.7354 - val_loss: 1.7350 - val_acc: 0.4467
# Epoch 24/51
# 3500/3500 [==============================] - 0s 37us/step - loss: 0.7607 - acc: 0.7414 - val_loss: 1.7559 - val_acc: 0.4540
# Epoch 25/51
# 3500/3500 [==============================] - 0s 37us/step - loss: 0.7429 - acc: 0.7500 - val_loss: 1.7639 - val_acc: 0.4473
# Epoch 26/51
# 3500/3500 [==============================] - 0s 35us/step - loss: 0.7269 - acc: 0.7566 - val_loss: 1.7952 - val_acc: 0.4513
# Epoch 27/51
# 3500/3500 [==============================] - 0s 33us/step - loss: 0.7100 - acc: 0.7594 - val_loss: 1.7926 - val_acc: 0.4580
# Epoch 28/51
# 3500/3500 [==============================] - 0s 31us/step - loss: 0.6971 - acc: 0.7680 - val_loss: 1.8143 - val_acc: 0.4587
# Epoch 29/51
# 3500/3500 [==============================] - 0s 30us/step - loss: 0.6874 - acc: 0.7746 - val_loss: 1.8397 - val_acc: 0.4573
# Epoch 30/51
# 3500/3500 [==============================] - 0s 31us/step - loss: 0.6685 - acc: 0.7740 - val_loss: 1.8569 - val_acc: 0.4600
# Epoch 31/51
# 3500/3500 [==============================] - 0s 33us/step - loss: 0.6581 - acc: 0.7780 - val_loss: 1.8737 - val_acc: 0.4607
# Epoch 32/51
# 3500/3500 [==============================] - 0s 34us/step - loss: 0.6412 - acc: 0.7903 - val_loss: 1.8839 - val_acc: 0.4620
# Epoch 33/51
# 3500/3500 [==============================] - 0s 37us/step - loss: 0.6281 - acc: 0.7971 - val_loss: 1.9084 - val_acc: 0.4587
# Epoch 34/51
# 3500/3500 [==============================] - 0s 37us/step - loss: 0.6208 - acc: 0.7931 - val_loss: 1.9412 - val_acc: 0.4500
# Epoch 35/51
# 3500/3500 [==============================] - 0s 32us/step - loss: 0.6071 - acc: 0.7989 - val_loss: 1.9389 - val_acc: 0.4607
# Epoch 36/51
# 3500/3500 [==============================] - 0s 31us/step - loss: 0.5952 - acc: 0.8060 - val_loss: 1.9674 - val_acc: 0.4587
# Epoch 37/51
# 3500/3500 [==============================] - 0s 30us/step - loss: 0.5813 - acc: 0.8111 - val_loss: 2.0132 - val_acc: 0.4520
# Epoch 38/51
# 3500/3500 [==============================] - 0s 31us/step - loss: 0.5744 - acc: 0.8100 - val_loss: 2.0221 - val_acc: 0.4633
# Epoch 39/51
# 3500/3500 [==============================] - 0s 33us/step - loss: 0.5610 - acc: 0.8186 - val_loss: 2.0291 - val_acc: 0.4573
# Epoch 40/51
# 3500/3500 [==============================] - 0s 33us/step - loss: 0.5497 - acc: 0.8140 - val_loss: 2.0514 - val_acc: 0.4560
# Epoch 41/51
# 3500/3500 [==============================] - 0s 32us/step - loss: 0.5399 - acc: 0.8234 - val_loss: 2.0747 - val_acc: 0.4567
# Epoch 42/51
# 3500/3500 [==============================] - 0s 30us/step - loss: 0.5317 - acc: 0.8283 - val_loss: 2.0966 - val_acc: 0.4547
# Epoch 43/51
# 3500/3500 [==============================] - 0s 31us/step - loss: 0.5258 - acc: 0.8277 - val_loss: 2.1334 - val_acc: 0.4533
# Epoch 44/51
# 3500/3500 [==============================] - 0s 37us/step - loss: 0.5154 - acc: 0.8317 - val_loss: 2.1408 - val_acc: 0.4620
# Epoch 45/51
# 3500/3500 [==============================] - 0s 37us/step - loss: 0.5044 - acc: 0.8371 - val_loss: 2.1582 - val_acc: 0.4607
# Epoch 46/51
# 3500/3500 [==============================] - 0s 38us/step - loss: 0.4993 - acc: 0.8383 - val_loss: 2.1981 - val_acc: 0.4587
# Epoch 47/51
# 3500/3500 [==============================] - 0s 37us/step - loss: 0.4866 - acc: 0.8440 - val_loss: 2.2170 - val_acc: 0.4660
# Epoch 48/51
# 3500/3500 [==============================] - 0s 37us/step - loss: 0.4786 - acc: 0.8491 - val_loss: 2.2585 - val_acc: 0.4653
# Epoch 49/51
# 3500/3500 [==============================] - 0s 38us/step - loss: 0.4715 - acc: 0.8514 - val_loss: 2.2580 - val_acc: 0.4633
# Epoch 50/51
# 3500/3500 [==============================] - 0s 36us/step - loss: 0.4636 - acc: 0.8529 - val_loss: 2.2814 - val_acc: 0.4613
# Epoch 51/51
# 3500/3500 [==============================] - 0s 32us/step - loss: 0.4542 - acc: 0.8560 - val_loss: 2.3126 - val_acc: 0.4687
# CPU times: user 1min 1s, sys: 16.2 s, total: 1min 17s
# Wall time: 27.5 s

# %%
f, [ax1, ax2] = plt.subplots(1, 2, sharey=True, figsize=(12, 5))

for name, perf in perf_histories.items():
    ax1.plot(perf['acc'], label=name)
    ax2.plot(perf['val_acc'], label=name)

ax1.set_title('Train')
ax2.set_title('Test')

for ax in [ax1, ax2]:
    ax.set_xlabel('Epoch')
    ax.set_ylabel('Accuracy')

ax2.legend(title='Model', bbox_to_anchor=(1.5, 1))

plt.suptitle('Models Performance')
plt.show()

# %% [markdown]
# ## Node importance

# %%
plt.figure(figsize=(8, 6))

for i, (name, weights_history) in enumerate(weights_histories.items()):
    avgs = []
    stds = []
    for epoch_weights in weights_history:
        flattened_weights = np.concatenate([
            abs(w).reshape(-1)
            for w in epoch_weights
        ])
        avgs.append(flattened_weights.mean())
        stds.append(flattened_weights.std())
        
    avgs = np.array(avgs)
    stds = np.array(stds) * .025
    
    color = f'C{i}'
    plt.plot(avgs, label=name, c=color)
    plt.fill_between(range(len(weights_history)), avgs-stds, avgs+stds, 
                     color=color, alpha=.1)
    
plt.xlabel('Epoch')
plt.ylabel('Absolute weights\n avg ± std')

plt.title('Weights History')
plt.legend()
plt.show()

# %%
def make_weights_graph(w: [np.array]) -> nx.Graph:
    G = nx.DiGraph()
    weights = w[::2]

    # layer zero is the input
    for l in range(len(layer_sizes)):
        w = abs(weights[l])

        for n1 in range(w.shape[0]):
            for n2 in range(w.shape[1]):
                G.add_edge(
                    f'layer{l}_node{n1}',
                    f'layer{l+1}_node{n2}',
                    weight=w[n1, n2]
                )
    return G

# %%
epochs_mod = 25

# %%
# %%time
pr_histories = {}
for name, weights_history in weights_histories.items():    
    prs = []
    for i, w in enumerate(weights_history):
        if i % epochs_mod == 0:
            G = make_weights_graph(w)
            pr = nx.pagerank(G)
        else:
            pr = {}
        prs.append(pd.Series(pr))
    pr_histories[name] = prs
# Out:
# CPU times: user 51 s, sys: 70.3 ms, total: 51.1 s
# Wall time: 51.1 s

# %%
lim = .0045

# %%
for i, (model, prs) in enumerate(pr_histories.items()):
    df = pd.DataFrame(prs)
    df['epoch'] = df.index
    df = df.melt(id_vars='epoch', value_name='PR')
    
    #print(f'{model} variation of distribution means, by epoch:', df.groupby('Epoch').PR.mean().std())
    df = df[(df.epoch % epochs_mod) == 0]  # keep only epochs divisible by epoch_mod
    
    joyplot(df, column='PR', by='epoch', 
            bins=40, range_style='own', ylim=lim,
            figsize=(5, 3),
            color=f'C{i}', linecolor='white')

    plt.xlabel('PageRank')
    plt.title(model)
    plt.show()

# %%
plt.figure(figsize=(20, 4))
plt.suptitle('Final Node Importance')

for i, (model, prs) in enumerate(pr_histories.items()):
    pr = prs[-1]
    
    plt.subplot(1, 4, i+1)
    pr.hist(bins=15, 
            grid='off', color=f'C{i}')
    
    plt.title(model)
    plt.xlim(None, lim)
    plt.xlabel('Page Rank')
    
    plt.locator_params(axis='x', nbins=5)
