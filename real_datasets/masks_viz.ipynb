# %%
# %load_ext autoreload
# %autoreload 2

# %%
from connections_generation import current_cond_dists, generate_masks
from viz import cond_dists_heatmap, univar_hists, masks_time_heatmaps

# %%
dists = current_cond_dists()
cond_dists_heatmap(dists)

# %%
univar_hists(dists)

# %%
layer_sizes = [32, 32, 32, 16, 16, 5]

# %%
masks = generate_masks(layer_sizes, dists)
masks_time_heatmaps(len(layer_sizes), masks)
